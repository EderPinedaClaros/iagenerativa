# %% [markdown]
# ## Usando el modelo de lenguaje Open Source de Meta - Llama2 (70B)

# %%
import os, getpass
from langchain_community.llms import Replicate

# %%
os.environ["REPLICATE_API_TOKEN"] = getpass.getpass("Ingresa tu API Key de Replicate : ")

# %%
llm = Replicate(
    model = "meta/llama-2-70b-chat:02e509c789964a7ea8736978a43525956ef40397be9033abf9fd2badfe68c9e3",
    model_kwargs = {"temperature" : 0.01, "max_length" : 500}
)

print(llm("dime quién fue Peter Drucker"))
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ---------------------------------------------------------------------------
# ReplicateError                            Traceback (most recent call last)
# Cell In[3], line 6
#       1 llm = Replicate(
#       2     model = "meta/llama-2-70b-chat:02e509c789964a7ea8736978a43525956ef40397be9033abf9fd2badfe68c9e3",
#       3     model_kwargs = {"temperature" : 0.01, "max_length" : 500}
#       4 )
# ----> 6 print(llm("dime quién fue Peter Drucker"))
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# ...

# %% [markdown]
# ## Usando el modelo de lenguaje Open Source de Mixtral (8x7b)

# %%
llm = Replicate(
    model = "mistralai/mixtral-8x7b-instruct-v0.1:7b3212fbaf88310cfef07a061ce94224e82efc8403c26fc67e8f6c065de51f21",
    model_kwargs = {"temperature" : 0.01, "max_length" : 500}
)

print(llm("what is a Generative AI"))
